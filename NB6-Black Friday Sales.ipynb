# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/Datasets/Black Friday Sale/BlackFriday.csv')

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df['User_ID']
# Out:
# 0         1000001
# 1         1000001
# 2         1000001
# 3         1000001
# 4         1000002
#            ...
# 537572    1004737
# 537573    1004737
# 537574    1004737
# 537575    1004737
# 537576    1004737
# Name: User_ID, Length: 537577, dtype: int64

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529])

# %%
df['User_ID'].nunique()
# Out:
# 5891

# %% [markdown]
# 5891 unique users

# %%
df['Product_ID'].nunique()
# Out:
# 3623

# %% [markdown]
# 3623 unique products are there

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6])

# %%
df['Occupation'].nunique()
# Out:
# 21

# %%
df['Purchase'].sum()
# Out:
# 5017668378

# %%
df['Purchase'].mean()
# Out:
# 9333.859852635065

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Purchase'],
#       dtype='object')

# %%
for column in df.columns:
  print(column,":",df[column].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3623
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category_1 : 18
# Purchase : 17959

# %% [markdown]
# Gender column Analysis

# %%
len(df[df['Gender']=='M']),len(df[df['Gender']=='F'])
# Out:
# (405380, 132197)

# %%
data=pd.DataFrame({'Ratio':[len(df[df['Gender']=='M']),len(df[df['Gender']=='F'])]} , index=['Male','Female'])

# %%
data
# Out:
#          Ratio
# Male    405380
# Female  132197

# %%
data.plot.pie(y='Ratio',figsize=(6,6),autopct='%.1f')
##default figsize=(5,5)

# %%
df.groupby('Gender').size()
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %%
df.groupby('Gender').size().plot(kind='pie',autopct='%.1f',title='Gender Ratio',figsize=(6,6))

# %%
df.groupby('Gender').size().plot(kind='bar',title='Gender Ratio',figsize=(6,6))

# %%
df.groupby('Gender').sum()['Purchase']
# Out:
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
df.groupby('Gender').sum()['Purchase'].plot(kind='pie',autopct='%.1f')

# %%
df.groupby('Gender').mean()['Purchase'].plot(kind='pie',autopct='%.1f')

# %% [markdown]
# Analysis Age And Marital Status

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Datasets/Black Friday Sale/BlackFriday.csv')
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby('Age').size().plot(kind='bar',figsize=(12,6),title='Age Count')

# %% [markdown]
# Most customers from Age Group - 18 to 45

# %% [markdown]
# no. of customers from diff age groups

# %%
df.groupby('Age').size()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# dtype: int64

# %%
for i in df['Age'].unique() :
  print(i,':',len(df[df['Age']==i]))
# Out:
# 0-17 : 14707
# 55+ : 20903
# 26-35 : 214690
# 46-50 : 44526
# 51-55 : 37618
# 36-45 : 107499
# 18-25 : 97634

# %% [markdown]
# no. of unique products purchased by each age groups

# %%
for i in df['Age'].unique() :
  print(i,':',)
# Out:
# 0-17 :
# 55+ :
# 26-35 :
# 46-50 :
# 51-55 :
# 36-45 :
# 18-25 :

# %%
df[df['Age']=='18-25']['Product_ID'].unique()
# Out:
# array(['P00366542', 'P00190742', 'P00151842', ..., 'P00195142',
#        'P00091742', 'P00091042'], dtype=object)

# %%
df[df['Age']=='18-25']['Product_ID'].nunique()
# Out:
# 3213

# %%
for i in df['Age'].unique() :
  print(i,':',df[df['Age']==i]['Product_ID'].nunique())
# Out:
# 0-17 : 2300
# 55+ : 2573
# 26-35 : 3419
# 46-50 : 3099
# 51-55 : 2877
# 36-45 : 3318
# 18-25 : 3213

# %%
lst=[]
for i in df['Age'].unique() :
  lst.append((i,df[df['Age']==i]['Product_ID'].nunique()))

data=pd.DataFrame(lst, columns=['Age group','No. of Products'])
data
# Out:
#   Age group  No. of Products
# 0      0-17             2300
# 1       55+             2573
# 2     26-35             3419
# 3     46-50             3099
# 4     51-55             2877
# 5     36-45             3318
# 6     18-25             3213

# %%
data.plot(kind='bar',x='Age group',title='No. of unique Products in each age group',figsize=(12,6))

# %% [markdown]
# Name nd count of each unique product purchased by people of Age 18-25

# %%
df_pr=df[df['Age']=='18-25']
df_pr.groupby('Product_ID').size().sort_values(ascending=True)
# Out:
# Product_ID
# P00149042      1
# P00282542      1
# P00283442      1
# P00160842      1
# P00284342      1
#             ...
# P00046742    293
# P00237542    295
# P00110742    323
# P00112142    335
# P00265242    388
# Length: 3213, dtype: int64

# %% [markdown]
# Name nd count of each unique product purchased by people of each Age Group in ascending order

# %%
for i in df['Age'].unique():
  df_pr=df[df['Age']==i]
  print('\n Age-Group:', i,'\n',':',df_pr.groupby('Product_ID').size().sort_values(ascending=True) )
# Out:
#  Age-Group: 0-17
#  : Product_ID
# P0099842      1
# P00165942     1
# P00166342     1
# P00167642     1
# P00167742     1
#              ..
# P00000142    55
# P00242742    56
# P00112142    58
# P00145042    63
# P00255842    64
# Length: 2300, dtype: int64
#
#  Age-Group: 55+
#  : Product_ID
# P00256242      1
# P00300242      1
# P00070242      1
# P00354242      1
# P00070742      1
#             ...
# P00184942     70
# P00025442     70
# P00051442     78
# P00080342     79
# P00265242    104
# Length: 2573, dtype: int64
#
#  Age-Group: 26-35
#  : Product_ID
# P00133242      1
# P00280042      1
# P00137942      1
# P00312542      1
# P00204442      1
#             ...
# P00058042    584
# P00025442    595
# P00112142    597
# P00110742    627
# P00265242    732
# Length: 3419, dtype: int64
#
#  Age-Group: 46-50
#  : Product_ID
# P00207642      1
# P00318442      1
# P00134642      1
# P00134842      1
# P00135342      1
#             ...
# P00117942    118
# P00051442    120
# ...

# %%
df.groupby('Age').sum()['Purchase'].plot(kind='bar',figsize=(12,6), title='Amount Spent by each group Age')

# %%
df.groupby('Age').mean()['Purchase'].plot(kind='bar',figsize=(12,6), title='Amount Spent by each group Age')

# %%
df.groupby('Age').mean()['Purchase'].plot(kind='pie',figsize=(12,6), title='Amount Spent by each group Age',autopct='%.1f')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby('Marital_Status').size().plot(kind='pie',autopct='%.1f')

# %%
df=pd.read_csv('/content/drive/MyDrive/Datasets/Black Friday Sale/BlackFriday.csv')
del df['Product_Category_2']
del df['Product_Category_3']
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Age',hue='Gender',data=df)

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Gender',hue='Age',data=df)

# %%
sns.countplot(x=df['City_Category'])

# %%
sns.countplot(x='City_Category',hue='Age',data=df)

# %%
sns.countplot(x='Age',hue='City_Category',data=df)

# %%
df.groupby('City_Category').size().plot(kind='pie',autopct='%.1f')

# %%
sns.countplot(x='City_Category',hue='Gender',data=df)

# %%
df.groupby('City_Category').sum()['Purchase'].plot(kind='pie',autopct='%.1f')

# %% [markdown]
# out of 100% purchases,
# > 41 % purchases from city b alone and 26 % from city A and 32.7 from city c is there

# %%
df.groupby('City_Category').mean()['Purchase'].plot(kind='pie',autopct='%.1f')

# %% [markdown]
# Average spending is more in City C is most ,then City B followed by City A,
# So for Launching An expensive Product, We would prefer City B most irrrespective of the fact 41% purchases are from city B, as average Purchase matters more

# %%
import numpy as np
import pandas as pd
import seaborn as sns
df=pd.read_csv('/content/drive/MyDrive/Datasets/Black Friday Sale/BlackFriday.csv')
del df['Product_Category_2']
del df['Product_Category_3']
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'])

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind='pie',autopct='%.1f')

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'],hue=df['Gender'])

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'],hue=df['Marital_Status'])

# %%
sns.countplot(x=df['Stay_In_Current_City_Years'],hue=df['City_Category'])

# %%
sns.countplot(x=df['City_Category'],hue=df['Age'])

# %%
df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind='pie',autopct='%.1f')

# %%
df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind='bar')

# %%
df.groupby('Stay_In_Current_City_Years').mean()['Purchase'].plot(kind='bar')

# %%
sns.countplot(x=df['Occupation'])

# %%
df.groupby('Occupation').size().plot(kind='bar')

# %% [markdown]
# same as before one

# %%
df.groupby('Occupation').size().sort_values().plot(kind='bar')

# %%
df.groupby('Occupation').sum()['Purchase'].plot(kind='bar')

# %%
df.groupby('Occupation').mean()['Purchase'].plot(kind='bar')

# %%
sns.countplot(x=df['Occupation'],hue=df['Marital_Status'])

# %%
sns.countplot(x=df['Occupation'],hue=df['Gender'])

# %% [markdown]
# can find gender ratio in different occupation, generally males are more in most jobs but for example in job 9 females are more there.

# %%
df.head(1)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370

# %%
df.groupby('Occupation').nunique()['Purchase']
# Out:
# Occupation
# 0     12785
# 1     11305
# 2      9314
# 3      7790
# 4     12764
# 5      6520
# 6      8273
# 7     12042
# 8      1395
# 9      4089
# 10     6967
# 11     6313
# 12    10022
# 13     4694
# 14     9335
# 15     6433
# 16     9190
# 17    10821
# 18     4511
# 19     5338
# 20    10471
# Name: Purchase, dtype: int64

# %%
df.groupby('Occupation').nunique()['Product_ID'].plot(kind='bar')

# %%
df.groupby('Occupation').nunique()['Product_ID'].sort_values().plot(kind='bar')

# %% [markdown]
#  most no. of unique buyers from occupation -0

# %%
df.groupby('Product_Category_1').size().sort_values().plot(kind='bar')

# %%
df.groupby('Product_Category_1').sum()['Purchase'].sort_values().plot(kind='bar')

# %%
df.groupby('Product_Category_1').mean()['Purchase'].sort_values().plot(kind='bar')

# %%
df.groupby('Product_ID').sum()['Purchase'].sort_values().plot(kind='bar')
# Out:
# Error in callback <function flush_figures at 0x7fc55ad03e50> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %% [markdown]
# too many product_id 's

# %%
 df.groupby('Product_ID').sum()['Purchase'].nlargest(10).sort_values().plot(kind='bar')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
df=pd.read_csv('/content/drive/MyDrive/Datasets/Black Friday Sale/BlackFriday.csv')
del df['Product_Category_2']
del df['Product_Category_3']
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
l=[]

for i in range(len(df)):
  l.append(df['Gender'][i]+'_'+str(df['Marital_Status'][i]))

df['Gender__Marital_Status']=l

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#   Gender__Marital_Status
# 0                    F_0
# 1                    F_0
# 2                    F_0
# 3                    F_0
# ...

# %%
sns.countplot(x=df['Gender__Marital_Status'])

# %%
 sns.countplot(x=df['Age'],hue=df['Gender__Marital_Status'])

# %%
 sns.countplot(x=df['Product_Category_1'],hue=df['Gender__Marital_Status'])
